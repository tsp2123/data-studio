# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from cycler import cycler
import os

# %%
US_1 = pd.read_csv('US_Soma_Clean.csv')

# %%
US_1
# Out:
#            Country Number_Ordered                 Weapon  \
# 0       Australia              75         F/A-18A Hornet
# 1              NaN              2                  Perry
# 2              NaN              4                 TPS-77
# 3              NaN              4       Boeing-737 AEW&C
# 4              NaN          (600)           RIM-162 ESSM
# 5              NaN              2       Boeing-737 AEW&C
# 6              NaN           (72)              F-35A JSF
# 7              NaN          (250)                   JDAM
# 8              NaN             12          P-8A Poseidon
# 9         Belgium              44                  F-16A
# 10         Canada               3   Bell-206L LongRanger
# 11             NaN            100               Bell-412
# 12             NaN            152                M-113A3
# 13             NaN            147                   MTVL
# 14             NaN          (300)           RIM-162 ESSM
# ...

# %%
US_1.dropna(thresh=2 , inplace=True)

# %%
US_1
# Out:
#            Country Number_Ordered                 Weapon  \
# 0       Australia              75         F/A-18A Hornet
# 1              NaN              2                  Perry
# 2              NaN              4                 TPS-77
# 3              NaN              4       Boeing-737 AEW&C
# 4              NaN          (600)           RIM-162 ESSM
# 5              NaN              2       Boeing-737 AEW&C
# 6              NaN           (72)              F-35A JSF
# 7              NaN          (250)                   JDAM
# 8              NaN             12          P-8A Poseidon
# 9         Belgium              44                  F-16A
# 10         Canada               3   Bell-206L LongRanger
# 11             NaN            100               Bell-412
# 12             NaN            152                M-113A3
# 13             NaN            147                   MTVL
# 14             NaN          (300)           RIM-162 ESSM
# ...

# %%
US_1['Country'] = US_1['Country'].fillna(method='ffill')

# %%
US_1
# Out:
#            Country Number_Ordered                 Weapon  \
# 0       Australia              75         F/A-18A Hornet
# 1       Australia               2                  Perry
# 2       Australia               4                 TPS-77
# 3       Australia               4       Boeing-737 AEW&C
# 4       Australia           (600)           RIM-162 ESSM
# 5       Australia               2       Boeing-737 AEW&C
# 6       Australia            (72)              F-35A JSF
# 7       Australia           (250)                   JDAM
# 8       Australia              12          P-8A Poseidon
# 9         Belgium              44                  F-16A
# 10         Canada               3   Bell-206L LongRanger
# 11         Canada             100               Bell-412
# 12         Canada             152                M-113A3
# 13         Canada             147                   MTVL
# 14         Canada           (300)           RIM-162 ESSM
# ...

# %%
US_1
# Out:
#            Country Number_Ordered                 Weapon  \
# 0       Australia              75         F/A-18A Hornet
# 1       Australia               2                  Perry
# 2       Australia               4                 TPS-77
# 3       Australia               4       Boeing-737 AEW&C
# 4       Australia           (600)           RIM-162 ESSM
# 5       Australia               2       Boeing-737 AEW&C
# 6       Australia            (72)              F-35A JSF
# 7       Australia           (250)                   JDAM
# 8       Australia              12          P-8A Poseidon
# 9         Belgium              44                  F-16A
# 10         Canada               3   Bell-206L LongRanger
# 11         Canada             100               Bell-412
# 12         Canada             152                M-113A3
# 13         Canada             147                   MTVL
# 14         Canada           (300)           RIM-162 ESSM
# ...
