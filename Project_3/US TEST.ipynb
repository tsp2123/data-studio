# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from cycler import cycler
import os

# %%
US = pd.read_csv('US-Test-1.csv')

# %%
US
# Out:
#           Country  Number_Ordered                 Weapon          Weapon_Type  \
# 0     Afghanistan             NaN                    NaN                  NaN
# 1             NaN           188.0                  M-113                  APC
# 2             NaN           800.0      HMMWV Up-Armoured                  APV
# 3             NaN          4735.0      HMMWV Up-Armoured                  APV
# 4             NaN          4002.0      HMMWV Up-Armoured                  APV
# 5             NaN           237.0      HMMWV Up-Armoured                  APV
# 6             NaN          2566.0      HMMWV Up-Armoured                  APV
# 7             NaN            41.0         ASV-150/M-1117                  APC
# 8             NaN           240.0         ASV-150/M-1117                  APC
# 9             NaN             6.0    Cessna-180 Skywagon       Light aircraft
# 10            NaN            26.0     Cessna-208 Caravan   Light transport ac
# ...

# %%
US.dtypes
# Out:
# Country              object
# Number_Ordered      float64
# Weapon               object
# Weapon_Type          object
# Date_Ordered        float64
# Date_Delivered       object
# Number_Delivered     object
# Comments             object
# dtype: object

# %%
US['Country'] = US['Country'].fillna(method='ffill')

# %%
US
# Out:
#           Country  Number_Ordered                 Weapon          Weapon_Type  \
# 0     Afghanistan             NaN                    NaN                  NaN
# 1     Afghanistan           188.0                  M-113                  APC
# 2     Afghanistan           800.0      HMMWV Up-Armoured                  APV
# 3     Afghanistan          4735.0      HMMWV Up-Armoured                  APV
# 4     Afghanistan          4002.0      HMMWV Up-Armoured                  APV
# 5     Afghanistan           237.0      HMMWV Up-Armoured                  APV
# 6     Afghanistan          2566.0      HMMWV Up-Armoured                  APV
# 7     Afghanistan            41.0         ASV-150/M-1117                  APC
# 8     Afghanistan           240.0         ASV-150/M-1117                  APC
# 9     Afghanistan             6.0    Cessna-180 Skywagon       Light aircraft
# 10    Afghanistan            26.0     Cessna-208 Caravan   Light transport ac
# ...

# %%
US[US['Country']== 'Viet Nam']
# Out:
#        Country  Number_Ordered     Weapon Weapon_Type  Date_Ordered  \
# 4198  Viet Nam             NaN        NaN         NaN           NaN
# 4199  Viet Nam             1.0   Hamilton         OPV        2016.0
# 4200  Viet Nam             NaN        NaN         NaN           NaN
#
#      Date_Delivered Number_Delivered                            Comments
# 4198            NaN              NaN                                 NaN
# 4199           2017                1   Second-hand; for coast guard; aid
# 4200            NaN              NaN                                 NaN

# %%
US.dropna(thresh=2 , inplace=True)

# %%
US[US['Country']== 'Canada']
# Out:
#     Country  Number_Ordered                 Weapon            Weapon_Type  \
# 471  Canada             3.0   Bell-206L LongRanger       Light helicopter
# 472  Canada           100.0               Bell-412             Helicopter
# 473  Canada           152.0                M-113A3                    APC
# 474  Canada           147.0                   MTVL                    APC
# 475  Canada           300.0           RIM-162 ESSM                    SAM
# 476  Canada            28.0         H-92 Superhawk         ASW helicopter
# 477  Canada            17.0     C-130J-30 Hercules     Transport aircraft
# 478  Canada           500.0                   TAPV                    APC
# 479  Canada            24.0                LM-2500            Gas turbine
# 480  Canada           550.0         AIM-7M Sparrow                 BVRAAM
# 481  Canada            34.0         RGM-84 Harpoon      Anti-ship missile
# 482  Canada            12.0                 SPS-49       Air search radar
# ...

# %%
US
# Out:
#               Country  Number_Ordered                 Weapon  \
# 1         Afghanistan           188.0                  M-113
# 2         Afghanistan           800.0      HMMWV Up-Armoured
# 3         Afghanistan          4735.0      HMMWV Up-Armoured
# 4         Afghanistan          4002.0      HMMWV Up-Armoured
# 5         Afghanistan           237.0      HMMWV Up-Armoured
# 6         Afghanistan          2566.0      HMMWV Up-Armoured
# 7         Afghanistan            41.0         ASV-150/M-1117
# 8         Afghanistan           240.0         ASV-150/M-1117
# 9         Afghanistan             6.0    Cessna-180 Skywagon
# 10        Afghanistan            26.0     Cessna-208 Caravan
# 11        Afghanistan           744.0      HMMWV Up-Armoured
# 12        Afghanistan             6.0                MD-500E
# 13        Afghanistan            71.0         ASV-150/M-1117
# 14        Afghanistan           136.0         ASV-150/M-1117
# ...

# %%
US.to_csv('US_Final.csv')
