# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from cycler import cycler
import os

# %matplotlib inline

# %%
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family' : 'sans-serif',
    'font.sans-serif' : 'verdana',
    'font.weight' : 'medium',
    'axes.titleweight' : 'heavy',
    
    'axes.titlesize' : 'large',
    
    "figure.facecolor": "#FFFFFF",
    "axes.facecolor": "#FFFFFF",
    "axes.grid" : True,
    "axes.grid.axis" : "y",
    "grid.color"    : "#C7C7C7",
    "grid.linewidth": 2,
    
    "axes.spines.left" : False,
    "axes.spines.right" : False,
    "axes.spines.top" : False,
    
    "ytick.major.size": 0,     
    "ytick.minor.size": 0,
    
    "xtick.direction" : "in",
    "xtick.major.size" : 5,
    "xtick.color"      : "#191919",
    "xtick.major.pad"      : 4,      # distance to major tick label in points
    "xtick.minor.pad"      : 3.9,      # distance to the minor tick label in point
    
    "axes.edgecolor"    :"#191919",
    "axes.prop_cycle" : plt.cycler('color', ['#518595', '#009CD7', '#72D1F6', '#108F85','#F13E20', '#711300']),
    "axes.axisbelow" : True,
    
    "legend.loc": 'lower right'
                                   
    })

# %%
Healthcare_Violations = pd.read_csv('export.csv')

# %%
Healthcare_Violations
# Out:
#                                                 Company  \
# 0                                      THE ENSIGN GROUP
# 1                         A & B Homecare Solutions, LLC
# 2                       LOYOLA UNIVERSITY HEALTH SYSTEM
# 3                                           ABTTC, Inc.
# 4                                           ABTTC, Inc.
# 5                                           ABTTC, Inc.
# 6                                    Acadia Abilene LLC
# 7                        Acadia Healthcare Company, LLC
# 8                               Acadia Healthcare, LLC.
# 9                                  Accredo Health Group
# 10                              Addus Health Care, Inc.
# 11                               ADDUS HEALTHCARE, INC.
# 12                             AdminaStar Federal, Inc.
# 13                              Adventist Health System
# 14                 Adventist Health System/Sunbelt Inc.
# 15                 Adventist Health System/Sunbelt Inc.
# ...

# %%
Healthcare_Violations.Company.value_counts().plot(kind='barh')

# %%
Healthcare_Violations.Company.value_counts().head(10).plot(kind='barh')

# %%
Healthcare_Violations.Company.value_counts().head(10)
# Out:
# Kaiser Permanente                                         13
# American Medical Response                                 13
# SSM Health Care - St. Louis                               10
# KAISER PERMANENTE                                          8
# Kindred Healthcare                                         7
# Tenet Healthcare Corporation                               7
# Trinity Health                                             6
# Humana Inc.                                                6
# Adventist Health System Sunbelt Healthcare Corporation     6
# Sunrise Senior Living, Inc.                                5
# Name: Company, dtype: int64

# %%
Healthcare_Violations[Healthcare_Violations['Company'] == 'Kaiser Permanente']
# Out:
#                 Company     Parent Company Penalty Amount  \
# 382   Kaiser Permanente  Kaiser Permanente       $258,140
# 383   Kaiser Permanente  Kaiser Permanente        $75,000
# 384   Kaiser Permanente  Kaiser Permanente        $49,500
# 385   Kaiser Permanente  Kaiser Permanente        $32,170
# 386   Kaiser Permanente  Kaiser Permanente        $27,000
# 387   Kaiser Permanente  Kaiser Permanente        $19,000
# 388   Kaiser Permanente  Kaiser Permanente        $18,234
# 389   Kaiser Permanente  Kaiser Permanente        $14,400
# 390   Kaiser Permanente  Kaiser Permanente        $10,000
# 391   Kaiser Permanente  Kaiser Permanente        $10,000
# 392   Kaiser Permanente  Kaiser Permanente         $6,914
# 393   Kaiser Permanente  Kaiser Permanente         $5,000
# 1057  Kaiser Permanente  Kaiser Permanente     $1,400,000
#
#      Subtraction From Penalty  \
# 382                        $0
# 383                        $0
# 384                        $0
# ...

# %%
American_Medical_Response = Healthcare_Violations[Healthcare_Violations['Company'] == 'American Medical Response']

# %%
American_Medical_Response['Penalty Year'].value_counts()
# Out:
# 2005    3
# 2004    3
# 2011    2
# 2003    2
# 2012    1
# 2007    1
# 2000    1
# Name: Penalty Year, dtype: int64

# %%
American_Medical_Response = Healthcare_Violations[Healthcare_Violations['Company'] == 'Kaiser Permanente']

# %%
American_Medical_Response['Penalty Year'].value_counts().plot(kind='barh')
